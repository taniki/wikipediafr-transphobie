# %%
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm
import base64

tqdm.pandas()
from wekeypedia import WikipediaPage as Page

# %%
page = Page('Mary_Shelley', lang='fr')

# %%
revisions = (
    pd
    .DataFrame
    .from_records(page.get_revisions_list())
    .assign(
        diff = lambda df: df.revid.progress_apply(lambda x: page.get_diff(x)).fillna(''),
        deleted = lambda df: df['diff'].apply(lambda diff: page.extract_plusminus(diff)['deleted']),
        added = lambda df: df['diff'].apply(lambda diff: page.extract_plusminus(diff)['added']),
    )
    .set_index('revid')
)

revisions
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 1106/1106 [06:30<00:00,  2.83it/s]
#             parentid                     user   userid             timestamp  \
# revid
# 213909561  213909204                Punctilla  3894623  2024-04-02T17:55:56Z
# 213909204  213907613                Punctilla  3894623  2024-04-02T17:41:19Z
# 213907613  213907385  Jean-Christophe BENOIST    44331  2024-04-02T16:53:53Z
# 213907385  213899110            Toise on dort  4662387  2024-04-02T16:46:41Z
# 213899110  213899080           DarkVador79-UA  4553277  2024-04-02T11:38:11Z
# ...              ...                      ...      ...                   ...
# 36113          33447                  Mgimpel      203  2003-03-05T18:13:35Z
# 33447          15741                     Emma       68  2002-12-03T09:10:40Z
# 15741           4669     script de conversion        0  2002-10-31T10:12:05Z
# 4669            4668               Youssefsan        8  2002-05-27T09:49:34Z
# 4668               0               Youssefsan        8  2002-05-27T09:48:41Z
#
#              size                                      sha1  \
# revid
# 213909561  117811  2bfc455f5a505c71d760f94665d8207b6abd14be
# 213909204  117805  91d67258a1c6a26b25aff32edc9a3217cf749b3b
# 213907613  117803  6527512046bed02375da01bc143438af0ff9dc2c
# 213907385  117802  b50e097c57e23bc00fcb32442e5ccdf562da0cf4
# 213899110  117803  6527512046bed02375da01bc143438af0ff9dc2c
# ...           ...                                       ...
# 36113         427  bac7194b08a73d3906d8fd9a820d978764a16d07
# 33447         387  8aa9b2b52ee8bc7ece4ebaf44803b18cfee3fd18
# 15741         290  dc2ab2e03c89649f77e3ba05d256feb9ad513fc2
# 4669          290  dc2ab2e03c89649f77e3ba05d256feb9ad513fc2
# 4668          244  fb196bba8effee612e476a3a2c9b4bf0ea1e7e1b
#
#                                                      comment anon  \
# revid
# 213909561    /* Lac Léman et Frankenstein */m syntaxe & typo  NaN
# 213909204  /* Percy Bysshe Shelley */Naissance de son fil...  NaN
# 213907613  Pourquoi ? Les sources notables ne l'évitent p...  NaN
# 213907385                                           à éviter  NaN
# 213899110                                             mef RI  NaN
# ...                                                      ...  ...
# 36113               lien vers articles anglais et  esperanto  NaN
# 33447                                                         NaN
# 15741                                 Conversion automatique
# 4669                                                       *  NaN
# 4668                                         ajout d'un lien  NaN
#
#                                                         diff  \
# revid
# 213909561  <tr>\n  <td colspan="2" class="diff-lineno">Li...
# 213909204  <tr>\n  <td colspan="2" class="diff-lineno">Li...
# 213907613  <tr>\n  <td colspan="2" class="diff-lineno">Li...
# 213907385  <tr>\n  <td colspan="2" class="diff-lineno">Li...
# 213899110  <tr>\n  <td colspan="2" class="diff-lineno">Li...
# ...                                                      ...
# 36113      <tr>\n  <td colspan="2" class="diff-lineno">Li...
# 33447      <tr>\n  <td colspan="2" class="diff-lineno">Li...
# 15741
# 4669       <tr>\n  <td colspan="2" class="diff-lineno">Li...
# 4668
#
#                                                      deleted  \
# revid
# 213909561  [ Shelley, }}, , au {{s-|XVIII}}, je, sortis, ...
# 213909204                 [de son, et, de, celui, d’Harriet]
# 213907613                                           [auteur]
# 213907385                                          [auteure]
# 213899110  [date-, |, |1797|en, littérature, date-|1, |, ...
# ...                                                      ...
# 36113                                                     []
# 33447                                                     []
# 15741                                                     []
# 4669                                            [, , , , , ]
# 4668                                                      []
#
#                                                        added
# revid
# 213909561  [|Shelley, . ,  du {{s-|XVIII}}, [elle], sorti...
# 213909204                [du, qu’il a, conçu, avec, Harriet]
# 213907613                                          [auteure]
# 213907385                                           [auteur]
# 213899110  [(, ), Date de naissance,  , 1797, Date de déc...
# ...                                                      ...
# 36113               [[[eo:Mary SHELLEY]][[en:Mary Shelley]]]
# 33447      [, [[Frankenstein]] fut écrit en [[1818]] et e...
# 15741                                                     []
# 4669       [[[science fiction]] | [[littérature anglaise]...
# 4668                                                      []
#
# [1106 rows x 11 columns]

# %%
def count(text, marker): 
    return text.lower().count(marker.lower())

df = (
    revisions
    .assign(
        auteure = lambda df: df.added.apply(lambda x: count(' '.join(x), 'auteure')),
        auteur = lambda df: df.added.apply(lambda x: count(' '.join(x), 'auteur')) - df.auteure,
        autrice = lambda df: df.added.apply(lambda x: count(' '.join(x), 'autrice')),
    )
)

(
    df
    .query('timestamp >= "2020-01-01"')
    .assign(
        year = lambda df: pd.to_datetime(df.timestamp).dt.year
    )
    .groupby(['user'])
    [['auteur', 'auteure', 'autrice']]
    .sum()
    .sort_values('auteur', ascending=False)
)
# Out:
#                                          auteur  auteure  autrice
# user
# Sherwood6                                    22        7        0
# Do not follow                                 4        1        0
# Gnrc                                          2        0        0
# 91.160.179.105                                2        0        0
# Azurfrog                                      1        0        0
# ...                                         ...      ...      ...
# 79.91.223.71                                  0        0        4
# 78.113.181.106                                0        0        0
# 2A04:CEC0:11C7:6F4:68EB:C098:1EFC:A55E        0        0        0
# 2A02:8428:81A5:6501:212A:B9E5:2388:A778       0        0        0
# Éric Messel                                   0        0        0
#
# [96 rows x 3 columns]

# %%
(
    df
    .query('timestamp >= "2020-01-01"')
    .query('user=="Sherwood6"')
    .assign(
        year = lambda df: pd.to_datetime(df.timestamp).dt.year
    )
    .groupby(['year'])
    [['auteur', 'auteure', 'autrice']]
    .sum()
)
# Out:
#       auteur  auteure  autrice
# year
# 2022       0        3        0
# 2023       2        0        0
# 2024      20        4        0

# %%
def format_revid_index(revid, page):
    return f'<a href="https://fr.wikipedia.org/w/index.php?title={page}&diff=prev&oldid={revid}">{revid}</a>'

# %%
(
    df
    .query('timestamp >= "2020-01-01"')
    .query('user=="Sherwood6"')
    .query('auteur > 0')
    [['user', 'timestamp']]
    .style
    .format_index(lambda revid: format_revid_index(revid, 'Mary_Shelley'))
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5a438">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a438_level0_col0" class="col_heading level0 col0" >user</th>
#       <th id="T_5a438_level0_col1" class="col_heading level0 col1" >timestamp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >revid</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a438_level0_row0" class="row_heading level0 row0" ><a href="https://fr.wikipedia.org/w/index.php?title=Mary_Shelley&diff=prev&oldid=213884037">213884037</a></th>
#       <td id="T_5a438_row0_col0" class="data row0 col0" >Sherwood6</td>
#       <td id="T_5a438_row0_col1" class="data row0 col1" >2024-04-01T21:10:43Z</td>
#     </tr>
#     <tr>
#       <th id="T_5a438_level0_row1" class="row_heading level0 row1" ><a href="https://fr.wikipedia.org/w/index.php?title=Mary_Shelley&diff=prev&oldid=213867631">213867631</a></th>
#       <td id="T_5a438_row1_col0" class="data row1 col0" >Sherwood6</td>
#       <td id="T_5a438_row1_col1" class="data row1 col1" >2024-04-01T12:24:12Z</td>
#     </tr>
#     <tr>
#       <th id="T_5a438_level0_row2" class="row_heading level0 row2" ><a href="https://fr.wikipedia.org/w/index.php?title=Mary_Shelley&diff=prev&oldid=213845390">213845390</a></th>
#       <td id="T_5a438_row2_col0" class="data row2 col0" >Sherwood6</td>
#       <td id="T_5a438_row2_col1" class="data row2 col1" >2024-03-31T18:25:34Z</td>
#     </tr>
#     <tr>
#       <th id="T_5a438_level0_row3" class="row_heading level0 row3" ><a href="https://fr.wikipedia.org/w/index.php?title=Mary_Shelley&diff=prev&oldid=213845378">213845378</a></th>
#       <td id="T_5a438_row3_col0" class="data row3 col0" >Sherwood6</td>
#       <td id="T_5a438_row3_col1" class="data row3 col1" >2024-03-31T18:25:17Z</td>
#     </tr>
#     <tr>
#       <th id="T_5a438_level0_row4" class="row_heading level0 row4" ><a href="https://fr.wikipedia.org/w/index.php?title=Mary_Shelley&diff=prev&oldid=211725843">211725843</a></th>
#       <td id="T_5a438_row4_col0" class="data row4 col0" >Sherwood6</td>
#       <td id="T_5a438_row4_col1" class="data row4 col1" >2024-01-21T17:54:46Z</td>
#     </tr>
#     <tr>
#       <th id="T_5a438_level0_row5" class="row_heading level0 row5" ><a href="https://fr.wikipedia.org/w/index.php?title=Mary_Shelley&diff=prev&oldid=211587991">211587991</a></th>
#       <td id="T_5a438_row5_col0" class="data row5 col0" >Sherwood6</td>
#       <td id="T_5a438_row5_col1" class="data row5 col1" >2024-01-17T10:22:05Z</td>
#     </tr>
#     <tr>
#       <th id="T_5a438_level0_row6" class="row_heading level0 row6" ><a href="https://fr.wikipedia.org/w/index.php?title=Mary_Shelley&diff=prev&oldid=211410618">211410618</a></th>
#       <td id="T_5a438_row6_col0" class="data row6 col0" >Sherwood6</td>
#       <td id="T_5a438_row6_col1" class="data row6 col1" >2024-01-11T13:47:43Z</td>
#     </tr>
#     <tr>
#       <th id="T_5a438_level0_row7" class="row_heading level0 row7" ><a href="https://fr.wikipedia.org/w/index.php?title=Mary_Shelley&diff=prev&oldid=211286708">211286708</a></th>
#       <td id="T_5a438_row7_col0" class="data row7 col0" >Sherwood6</td>
#       <td id="T_5a438_row7_col1" class="data row7 col1" >2024-01-07T17:06:09Z</td>
#     </tr>
#     <tr>
#       <th id="T_5a438_level0_row8" class="row_heading level0 row8" ><a href="https://fr.wikipedia.org/w/index.php?title=Mary_Shelley&diff=prev&oldid=209316143">209316143</a></th>
#       <td id="T_5a438_row8_col0" class="data row8 col0" >Sherwood6</td>
#       <td id="T_5a438_row8_col1" class="data row8 col1" >2023-11-03T22:03:25Z</td>
#     </tr>
#     <tr>
#       <th id="T_5a438_level0_row9" class="row_heading level0 row9" ><a href="https://fr.wikipedia.org/w/index.php?title=Mary_Shelley&diff=prev&oldid=201919228">201919228</a></th>
#       <td id="T_5a438_row9_col0" class="data row9 col0" >Sherwood6</td>
#       <td id="T_5a438_row9_col1" class="data row9 col1" >2023-03-02T15:03:25Z</td>
#     </tr>
#   </tbody>
# </table>
